# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_excel('Tata IPL Players list (2).xlsx')
df
# Out:
#      List Sr. No.  Set No. 2023 Set First Name     Surname       Country  \
# 0               1        1      BA1     Mayank     Agarwal         India
# 1               2        1      BA1      Harry       Brook       England
# 2               3        1      BA1    Ajinkya      Rahane         India
# 3               4        1      BA1        Joe        Root       England
# 4               5        1      BA1      Rilee     Rossouw  South Africa
# ..            ...      ...      ...        ...         ...           ...
# 400           401       43    UAL10       Jack  Prestwidge     Australia
# 401           402       43    UAL10     Aditya     Sarvate         India
# 402           403       43    UAL10      Sagar     Solanki         India
# 403           404       43    UAL10   Prenelan    Subrayen  South Africa
# 404           405       43    UAL10    Bhagath       Varma         India
#
#     State Association        DOB  Age   Specialism  ...  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 405 entries, 0 to 404
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   List Sr. No.           405 non-null    int64
#  1   Set No.                405 non-null    int64
#  2   2023 Set               405 non-null    object
#  3   First Name             405 non-null    object
#  4   Surname                405 non-null    object
#  5   Country                405 non-null    object
#  6   State Association      273 non-null    object
#  7   DOB                    405 non-null    datetime64[ns]
#  8   Age                    405 non-null    int64
#  9   Specialism             405 non-null    object
#  10  Unnamed: 10            405 non-null    object
#  11  Unnamed: 11            405 non-null    object
#  12  Test caps              63 non-null     float64
#  13  ODI caps               100 non-null    float64
# ...

# %%
df1=df.copy()

# %%
k=df.isnull().sum()
k
# Out:
# List Sr. No.               0
# Set No.                    0
# 2023 Set                   0
# First Name                 0
# Surname                    0
# Country                    0
# State Association        132
# DOB                        0
# Age                        0
# Specialism                 0
# Unnamed: 10                0
# Unnamed: 11                0
# Test caps                342
# ODI caps                 305
# T20 caps                 297
# IPL                      272
# Previous IPLTeam(s)      272
# 2022 Team                338
# 2022 IPL                 338
# C/U/A                      0
# Reserve Price Rs Lakh      0
# dtype: int64

# %%
#filtering the players who have already experienced in international or ipl matches

# %%
#filling the column names

# %%
df.rename(columns={'Unnamed: 11': 'Bowling Medium'}, inplace=True)
df.rename(columns={'Unnamed: 10': 'Batting Medium'}, inplace=True)

# %%
#dropping unwanted columns

# %%
df.drop(['List Sr. No.','2023 Set','DOB'],axis=1,inplace=True)

# %%
df
# Out:
#      Set No. First Name     Surname       Country State Association  Age  \
# 0          1     Mayank     Agarwal         India              KSCA   32
# 1          1      Harry       Brook       England               NaN   24
# 2          1    Ajinkya      Rahane         India               MCA   34
# 3          1        Joe        Root       England               NaN   32
# 4          1      Rilee     Rossouw  South Africa               NaN   33
# ..       ...        ...         ...           ...               ...  ...
# 400       43       Jack  Prestwidge     Australia               NaN   27
# 401       43     Aditya     Sarvate         India               VCA   33
# 402       43      Sagar     Solanki         India              MPCA   23
# 403       43   Prenelan    Subrayen  South Africa               NaN   29
# 404       43    Bhagath       Varma         India              HYCA   24
#
#       Specialism Batting Medium            Bowling Medium  Test caps  \
# ...

# %%
df.rename(columns={'Unnamed: 10': 'Batting Medium'}, inplace=True)
df
# Out:
#      Set No. First Name     Surname       Country State Association  Age  \
# 0          1     Mayank     Agarwal         India              KSCA   32
# 1          1      Harry       Brook       England               NaN   24
# 2          1    Ajinkya      Rahane         India               MCA   34
# 3          1        Joe        Root       England               NaN   32
# 4          1      Rilee     Rossouw  South Africa               NaN   33
# ..       ...        ...         ...           ...               ...  ...
# 400       43       Jack  Prestwidge     Australia               NaN   27
# 401       43     Aditya     Sarvate         India               VCA   33
# 402       43      Sagar     Solanki         India              MPCA   23
# 403       43   Prenelan    Subrayen  South Africa               NaN   29
# 404       43    Bhagath       Varma         India              HYCA   24
#
#       Specialism Batting Medium            Bowling Medium  Test caps  \
# ...

# %%
df['Test caps']=df['Test caps'].fillna(0)
df
# Out:
#      Set No. First Name     Surname       Country State Association  Age  \
# 0          1     Mayank     Agarwal         India              KSCA   32
# 1          1      Harry       Brook       England               NaN   24
# 2          1    Ajinkya      Rahane         India               MCA   34
# 3          1        Joe        Root       England               NaN   32
# 4          1      Rilee     Rossouw  South Africa               NaN   33
# ..       ...        ...         ...           ...               ...  ...
# 400       43       Jack  Prestwidge     Australia               NaN   27
# 401       43     Aditya     Sarvate         India               VCA   33
# 402       43      Sagar     Solanki         India              MPCA   23
# 403       43   Prenelan    Subrayen  South Africa               NaN   29
# 404       43    Bhagath       Varma         India              HYCA   24
#
#       Specialism Batting Medium            Bowling Medium  Test caps  \
# ...

# %%
df['ODI caps']=df['ODI caps'].fillna(0)
df['Test caps']=df['Test caps'].fillna(0)
df['T20 caps']=df['T20 caps'].fillna(0)
df['State Association']=df['State Association'].fillna('Foreign players')

# %%
df['State Association']=df['State Association'].fillna('Foreign players')

# %%
df['IPL']=df['IPL'].fillna(0)

# %%
df['Previous IPLTeam(s)']=df['Previous IPLTeam(s)'].fillna('nill')

# %%
df['2022 Team']=df['2022 Team'].fillna('nill')

# %%
df['2022 IPL']=df['2022 IPL'].fillna(0)

# %%
df.isnull().sum()
# Out:
# Set No.                  0
# First Name               0
# Surname                  0
# Country                  0
# State Association        0
# Age                      0
# Specialism               0
# Batting Medium           0
# Bowling Medium           0
# Test caps                0
# ODI caps                 0
# T20 caps                 0
# IPL                      0
# Previous IPLTeam(s)      0
# 2022 Team                0
# 2022 IPL                 0
# C/U/A                    0
# Reserve Price Rs Lakh    0
# dtype: int64

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(6, 8))  # Adjust figsize as needed

# Create boxplot for 'Age'
ax1.boxplot(df['Age'])
ax1.set_title('Boxplot for Age')
ax1.set_ylabel('Values')

# Create boxplot for 'Reserve Price Rs Lakh'
ax2.boxplot(df['Reserve Price Rs Lakh'])
ax2.set_title('Boxplot for Reserve Price Rs Lakh')
ax2.set_ylabel('Values')

# Adjust spacing between subplots
plt.tight_layout()

# Show the subplots
plt.show()

# %%
df
# Out:
#      Set No. First Name     Surname       Country State Association  Age  \
# 0          1     Mayank     Agarwal         India              KSCA   32
# 1          1      Harry       Brook       England   Foreign players   24
# 2          1    Ajinkya      Rahane         India               MCA   34
# 3          1        Joe        Root       England   Foreign players   32
# 4          1      Rilee     Rossouw  South Africa   Foreign players   33
# ..       ...        ...         ...           ...               ...  ...
# 400       43       Jack  Prestwidge     Australia   Foreign players   27
# 401       43     Aditya     Sarvate         India               VCA   33
# 402       43      Sagar     Solanki         India              MPCA   23
# 403       43   Prenelan    Subrayen  South Africa   Foreign players   29
# 404       43    Bhagath       Varma         India              HYCA   24
#
#       Specialism Batting Medium            Bowling Medium  Test caps  \
# ...

# %%
plt.figure(figsize=(14,5))
plt.subplot(121)
c=df['C/U/A'].value_counts()
plt.pie(c,labels=c.index,autopct='%.2f%%',startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x14367bc3ac0>,
# ...
#  [Text(-0.08949461664949693, -1.0963533707663602, 'Uncapped'),
#   Text(0.12346394021967004, 1.0930492465874693, 'Capped'),
#   Text(-0.820307740749655, 0.7328677987646864, 'Associate')],
#  [Text(-0.04881524544518014, -0.5980109295089236, '69.63%'),
#   Text(0.06734396739254729, 0.5962086799568013, '29.38%'),
#   Text(-0.4474405858634481, 0.3997460720534653, '0.99%')])

# %%
#there are more uncapped players(69.63%) than capped players(29.38%)

# %%
plt.figure(figsize=(12,4))
plt.subplot(121)
ax=sb.countplot(x='Specialism',data=df)
total = len(df['Specialism'])
for p in ax.patches:
        height = p.get_height()
        ax.annotate(f'{height/total:.0%}', (p.get_x() + p.get_width() / 2., height), ha='center', va='bottom')
        
    
    
plt.show()

# %%
#in the ipl allrounder are mostly registered followed by bowler and the least is wicket keeper.

# %%
df['Full Name'] = df['First Name'] + ' ' + df['SurName']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\.ipython\extensions\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\.ipython\extensions\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\.ipython\extensions\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SurName'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df.columns

# %%
dfg=df[df['2022 Team']!='nill']
team_countss=dfg.groupby(['2022 Team'])['Reserve Price Rs Lakh'].count()
team_countss.plot(kind='bar', figsize=(10, 6), color='red')
plt.title('amount spend by the each team')
plt.xlabel('Team')
plt.ylabel('amount')
plt.xticks(rotation=45)  


plt.tight_layout()
plt.show()

# %%
dfg=df[df['2022 Team']!='nill']
team_countss=dfg.groupby(['2022 Team','Reserve Price Rs Lakh'])['Reserve Price Rs Lakh'].count()
team_countss
# Out:
# 2022 Team  Reserve Price Rs Lakh
# CSK        20                       3
#            30                       1
#            200                      2
# DC         20                       2
#            50                       1
# GT         50                       3
#            150                      1
# KKR        20                       4
#            40                       1
#            50                       2
#            100                      1
# LSG        20                       1
#            50                       2
#            100                      2
#            200                      1
# MI         20                       6
#            50                       3
#            75                       1
#            150                      1
#            200                      1
# PBKS       20                       4
#            40                       1
#            50                       2
#            100                      1
# ...

# %%
plt.figure(figsize=(15,5))
plt.subplot(121)
sb.countplot(x='Specialism',hue='C/U/A',data=df)
# Out:
# <AxesSubplot:xlabel='Specialism', ylabel='count'>

# %%
#uncapped players are mostly all rounders and capped players are mostly bowlers

# %%
r=df.groupby('Batting Medium')['Country'].count()
r
# Out:
# Batting Medium
# LHB    109
# RHB    296
# Name: Country, dtype: int64

# %%
r=df.groupby('Batting Medium')['Country'].count()
plt.figure(figsize=(15,8))
sb.barplot(x = r.index, y = r.values)
# Out:
# <AxesSubplot:xlabel='Batting Medium'>

# %%
#right hand batsmen are more compares to the left hand batsmen

# %%
plt.hist(df['Age'], bins=5, edgecolor='black')
# Out:
# (array([ 19., 123., 157.,  92.,  14.]),
#  array([15., 20., 25., 30., 35., 40.]),
#  <BarContainer object of 5 artists>)

# %%
#players whose  age are between 25 and 30 are mostly registered

# %%
df.isnull().sum()
# Out:
# Set No.                  0
# First Name               0
# Surname                  0
# Country                  0
# State Association        0
# Age                      0
# Specialism               0
# Batting Medium           0
# Bowling Medium           0
# Test caps                0
# ODI caps                 0
# T20 caps                 0
# IPL                      0
# Previous IPLTeam(s)      0
# 2022 Team                0
# 2022 IPL                 0
# C/U/A                    0
# Reserve Price Rs Lakh    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Set No.', 'First Name', 'Surname', 'Country', 'State Association',
#        'Age', 'Specialism', 'Batting Medium', 'Bowling Medium', 'Test caps',
#        'ODI caps', 'T20 caps', 'IPL', 'Previous IPLTeam(s)', '2022 Team',
#        '2022 IPL', 'C/U/A', 'Reserve Price Rs Lakh'],
#       dtype='object')

# %%
plt.scatter(df['Test caps'],df['Reserve Price Rs Lakh'] , label='Data Points', color='blue', marker='o')

# %%
#players whose played test matches between 10 and 20 are having more base price

# %%
fp = df[(df['Age'] >= 20) & (df['Age'] <= 26) & (df['T20 caps']>10)]
plt.figure(figsize=(10, 6))
plt.bar(fp['First Name'], fp['T20 caps'])
plt.xlabel('Player Name')
plt.ylabel('T20 Caps')
plt.title('Players Aged 20-26 with More Than 10 T20 Caps')
plt.yticks(fp['T20 caps'])
plt.xticks(rotation=45)
plt.tight_layout()

# %%
dff=df[df['2022 Team']!='nill']
team_counts=dff.groupby(['2022 Team'])['First Name'].count()
team_counts.plot(kind='bar', figsize=(10, 6), color='skyblue')
plt.title(' count of players released by the team')
plt.xlabel('Team')
plt.ylabel('Number of Players')
plt.xticks(rotation=45)  


plt.tight_layout()
plt.show()

# %%
#mi bought more no of players and rcb bought less no of players

# %%
cross_tab = pd.crosstab(df['2022 Team'], df['Specialism'])
cross_tab
# Out:
# Specialism  ALL-ROUNDER  BATSMAN  BOWLER  WICKETKEEPER
# 2022 Team
# CSK                   1        1       3             1
# DC                    0        2       0             1
# GT                    1        2       1             0
# KKR                   2        1       2             3
# LSG                   1        1       4             0
# MI                    4        1       6             1
# PBKS                  4        1       3             0
# RCB                   0        1       0             1
# RR                    4        2       2             0
# SRH                   5        1       2             2
# nill                132       49     108            49

# %%
cross_tab = pd.crosstab(df['2022 Team'], df['Specialism'])
cross_tab
#dfl=df[df['2022 Team']!='nill']
plt.figure(figsize=(10, 6))
sb.heatmap(cross_tab, annot=True, fmt='d', cmap='YlGnBu')
plt.title('players')
plt.xlabel('specialism')
plt.ylabel('Teams')
plt.tight_layout()
plt.show()

# %%
df['IPL'] = df['IPL'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 405 entries, 0 to 404
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Set No.                405 non-null    int64
#  1   First Name             405 non-null    object
#  2   Surname                405 non-null    object
#  3   Country                405 non-null    object
#  4   State Association      405 non-null    object
#  5   Age                    405 non-null    int64
#  6   Specialism             405 non-null    object
#  7   Batting Medium         405 non-null    object
#  8   Bowling Medium         405 non-null    object
#  9   Test caps              405 non-null    float64
#  10  ODI caps               405 non-null    float64
#  11  T20 caps               405 non-null    float64
#  12  IPL                    405 non-null    int32
#  13  Previous IPLTeam(s)    405 non-null    object
# ...

# %%
dpr=df[df['IPL']>=100]

# %%
dpr
# Out:
#     Set No. First Name  Surname Country State Association  Age Specialism  \
# 0         1     Mayank  Agarwal   India              KSCA   32    BATSMAN
# 2         1    Ajinkya   Rahane   India               MCA   34    BATSMAN
# 68       11     Manish   Pandey   India              KSCA   33    BATSMAN
# 70       11    Mandeep    Singh   India               PCA   31    BATSMAN
# 85       13    Sandeep   Sharma   India              UTCA   29     BOWLER
# 93       15     Piyush   Chawla   India              GUCA   34     BOWLER
# 94       15       Amit   Mishra   India               HCA   40     BOWLER
#
#    Batting Medium         Bowling Medium  Test caps  ODI caps  T20 caps  IPL  \
# 0             RHB     RIGHT ARM Off Spin       21.0       5.0       0.0  113
# 2             RHB                      -       82.0      90.0      20.0  158
# 68            RHB                      -        0.0      29.0      39.0  160
# ...

# %%
plt.figure(figsize=(8, 6))
plt.bar(dpr['First Name'], dpr['IPL'], color='skyblue')
plt.title('Players with More  IPL matches')
plt.xlabel('Player Name')
plt.ylabel('Test Caps')
plt.xticks(rotation=60)
plt.tight_layout()
plt.show()

# %%
#piyush has played more ipl matches than others

# %%
state_counts = df["State Association"].value_counts()
plt.figure(figsize=(12, 6))
state_counts.plot(kind="bar")
plt.title("Distribution of Players Among State Associations")
plt.xlabel("State Association")
plt.ylabel("Number of Players")
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels for readability
plt.tight_layout()
plt.show()
